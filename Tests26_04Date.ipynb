# %% [markdown]
# Для тестирования можно использовать библиотеку pytest (как в примере: https://youtu.be/1HtEPEn4-LY)

# %%
all_tests = [
' за сегодня ' ,
' за вчера ' ,
' за позавчера ' ,
' за последний день ' ,
' за последнюю неделю ' ,
' за последний месяц ' ,
' за последний квартал ' ,
' за последнее полугодие ' ,
' за последний год ' ,
' за последние два дня ' ,
' за последние три недели ' ,
' за последние четыре месяца ' ,
' за последние два квартал ' ,
' за последние три года ' ,
' за прошлый день ' ,
' за прошлую неделю ' ,
' за прошлый месяц ' ,
' за прошлый квартал ' ,
' за прошлое полугодие ' ,
' за прошлый год ' ,
' за два прошлых дня ' ,
' за две прошлых недели ' ,
' за три прошлых месяца ' ,
' за четыре прошлых года ' ,
' за предыдущий день ' ,
' за предыдущую неделю ' ,
' за предыдущий месяц ' ,
' за предыдущий квартал ' ,
' за предыдущее полугодие ' ,
' за предыдущий год ' ,
' за два предыдущих дня ' ,
' за две предыдущих недели ' ,
' за три предыдущих месяца ' ,
' за четыре предыдущих года ' ,
' за день ' ,
' за один день ' ,
' за три дня ' ,
' за десять дней ' ,
' за двадцать дней ' ,
' за 1 день ' ,
' за 3 дня ' ,
' за 10 дней ' ,
' за неделю ' ,
' за одну неделю ' ,
' за три недели ' ,
' за десять недель ' ,
' за 1 неделю ' ,
' за 3 недели ' ,
' за 10 недель ' ,
' за месяц ' ,
' за один месяц ' ,
' за три месяца ' ,
' за десять месяцев ' ,
' за 1 месяц ' ,
' за 2 месяца ' ,
' за 3 месяца ' ,
' за 10 месяцев ' ,
' за квартал ' ,
' за один квартал ' ,
' за три квартала ' ,
' за 1 квартал ' ,
' за 3 месяца ' ,
' за полугодие ' ,
' за два полугодия ' ,
' за 2 полугодя ' ,
' за год ' ,
' за один год ' ,
' за три года ' ,
' за десять лет ' ,
' за 1 год ' ,
' за 3 года ' ,
' три дня назад ' ,
' две недели назад ' ,
' два месяца назад ' ,
' полгода назад ' ,
' год назад ' ,
' на прошлой неделе ' ,
' за январь ' ,
' за март 2012го ' ,
' за апрель 2008 ' ,
' за август 2019 года ' ,
' за 2011 год ' ,
' за 2012й ' ,
' за 2021 ' ,
' за второй квартал ' ,
' за июнь прошлого года ' ,
' за август позапрошлого года ' ,
' за первый квартал текущего года ' ,
' за третий квартал позапрошлого года ' ,
' за 2й квартал прошлого года ' ,
' за третий квартал предыдущего года ' ,
' за март месяц прошедшего года ' ,
' за февраль прошлого года ' ,
' за второе полугодие прошлого года ' ,
' за 2 неделю прошлого месяца ' ,
' за первую неделю сентября прошлого года ' ,
' за первый месяц 2020 года ' ,
' за второй день третьей недели второго квартала ' ,
' за 4 квартал 2020 года ' ,
' за три недели первого квартала 2019 года ' ,
' за вторую неделю сентября 2020 года ' ,
' с апреля 2010 года ' ,
' после апреля 2010 года ' ,
' за апрель 2010 года ' ,
' с мая по июнь 2020 года ' ,
' с февраля по апрель позапрошлого года ' ,
' до июня текущего года ' ,
' с января 2011 года по март 2012го ' ,
' с июня по декабрь ' ,
' с 2001 по 2012 гг ' ,
' с первого до десятого апреля 2019 года ' ,
' с августа по октябрь ' ,
' в апреле ' ,
' в марте 2012 года ' ,
' в апреле прошлого года ' ,
' в мае позапрошлого года ' ,
' во втором квартале ' ,
' в прошлом месяце ' ,
' в прошлом году ' ,
' в позапрошлом году ' ,
' в 2018 году ' ,
' в 2005-2010 годах ' ,
' в 2012-2013 гг ' ,
' с 2012 по 2013 ' ,
' c 01.10 по 01.12 ' ,
' с 01.02.2003 по 21.12.2012 ' ,
' с 01.02 по 21.12 ' ,
' с первого октября по первое декабря 2012 года ' ,
' с двадцать второго числа апреля месяца ' ,
' с первого полугодия прошлого года ' ,
' с третьего квартала текущего года ' ,
' со второй по четвертую неделю первого квартала ' ,
' с первого по третий квартал прошлого года ' ,
' с 1 по 3 неделю сентября 2013 года ' ,
' со второго квартала 2019 по третий квартал 2020 ' ,
' с января по май 2019 и с первого по третий квартал прошлого года ' ,
' отчет Павлова на портале за прошлую неделю ' ,
' отчет Иванов вики xlsx за прошлый месяц ' ,
' Иванов справка о доходах за прошлый год ' ,
' справка Сидорова pdf три дня назад ' ,
' квитанция от Ивана Петровича на прошлой неделе pdf ' ,
' квартальный отчет Светланы docx за прошлый квартал ' 
]

# %%
# !pip install natasha==1.4.0
# Out:
# Collecting natasha==1.4.0
#   Using cached natasha-1.4.0-py3-none-any.whl (34.4 MB)
# Requirement already satisfied: yargy>=0.14.0 in /Users/evgenia/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages (from natasha==1.4.0) (0.14.0)
# Requirement already satisfied: ipymarkup>=0.8.0 in /Users/evgenia/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages (from natasha==1.4.0) (0.9.0)
# Collecting razdel>=0.5.0
#   Using cached razdel-0.5.0-py3-none-any.whl (21 kB)
# Collecting navec>=0.9.0
#   Using cached navec-0.10.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: pymorphy2 in /Users/evgenia/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages (from natasha==1.4.0) (0.8)
# Collecting slovnet>=0.3.0
#   Using cached slovnet-0.5.0-py3-none-any.whl (49 kB)
# Collecting intervaltree>=3
#   Using cached intervaltree-3.1.0-py2.py3-none-any.whl
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /Users/evgenia/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages (from intervaltree>=3->ipymarkup>=0.8.0->natasha==1.4.0) (2.3.0)
# Collecting numpy
#   Using cached numpy-1.20.2-cp38-cp38-macosx_10_9_x86_64.whl (16.0 MB)
# Requirement already satisfied: docopt>=0.6 in /Users/evgenia/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages (from pymorphy2->natasha==1.4.0) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7 in /Users/evgenia/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages (from pymorphy2->natasha==1.4.0) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts<3.0,>=2.4 in /Users/evgenia/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages (from pymorphy2->natasha==1.4.0) (2.4.393442.3710985)
# Installing collected packages: numpy, razdel, navec, intervaltree, slovnet, natasha
#   Attempting uninstall: intervaltree
#     Found existing installation: intervaltree 2.1.0
#     Uninstalling intervaltree-2.1.0:
#       Successfully uninstalled intervaltree-2.1.0
#   Attempting uninstall: natasha
#     Found existing installation: natasha 0.9.0
#     Uninstalling natasha-0.9.0:
#       Successfully uninstalled natasha-0.9.0
# Successfully installed intervaltree-3.1.0 natasha-1.4.0 navec-0.10.0 numpy-1.20.2 razdel-0.5.0 slovnet-0.5.0

# %%
list(TOKENIZER('за'))# NUMR
# Out:
# [MorphToken(
#      value='за',
#      span=[0, 2),
#      type='RU',
#      forms=[Form('за', Grams(PREP))]
#  )]

# %%
lines = [
'за второй квартал предыдущего года ',
'за вторую неделю прошлого месяца ',
'за первую неделю сентября прошлого года ',
'за второй день третьей недели второго квартала ',
'за первый месяц 2020 года ',
'за три недели первого квартала 2019 года ',
'за 4 квартал 2020 года ',
'за три дня ',
'за прошлую неделю ',
'за предыдущий месяц ',
'с апреля 2010 года ',
'после апреля 2010 года ',
'за апрель 2010 года ',
'с мая по июнь 2020 года',
'с февраля по апрель позапрошлого года ',
'до июня текущего года ',
'за последние три года',
'в 2018 году ',
'с 01.10 по 01.12 ',
'со второй по четвертую неделю первого квартала ',
'со второго квартала  2019 по третий квартал 2020 ',
'с января по май 2019 и с первого по третий квартал прошлого года '
]

# %%
Quarter = fact(
        'Quarter',
        ['quarter_ordinal','quarter_cardinal','quarter_start_ordinal','quarter_end_ordinal'],
    )

# %%
class ExtractDate(object):

  def __init__(self):
        self.year = []
        self.quater = []
        self.month = []
        self.week = []
        self.day = [] 

        self.week_ordinal = []
        self.week_cardinal = []
        self.week_modifier = []
        self.week_start_ordinal= []
        self.week_end_ordinal= []

        self.quarter_ordinal= []
        self.quarter_cardinal= []
        self.quarter_start_ordinal= []
        self.quarter_end_ordinal= []

        self.month_modifier= []
        self.month_ordinal= []
        self.month_cardinal= []

        self.half_year = []
        self.count = []

        self.year_modifier= []
        self.year_cardinal= []
        self.year_start_modifier= []
        self.year_end_modifier= []

        self.date= []

        self.day_ordinal= []
        self.day_cardinal= []
        self.day_modifier = []

        self.start_date= []
        self.end_date= []
        

  def get_date(self):
      if self.year != None:
            print("Год: ", match.fact.year)
      if self.quater != None:
            print("Квартал: ", match.fact.quater)
      if self.mouth != None:
            print("Месяц: ", match.fact.mouth)
      if self.week != None:
            print("Неделя: ", match.fact.week)
      if self.day != None:
            print("День: ", match.fact.day)  

def skip_none(arr):
  #print("arr", arr)
  out = ''
  for el in arr:
    #print(el)
    if el != None:
      out = el
  return out    


def viz( date ,line, matches, count_date): 
  result = []
  #print(matches)
  for match in matches:
    #print("________________________")
    #print("Дата: ", line)
    #print(match.fact)
    #for chank in match.fact:
    #  if chank != None:
    #    print(chank)
    #display(match.tree.as_dot)
    date.quarter_cardinal.append(match.fact.quarter_cardinal)
    date.quarter_ordinal.append(match.fact.quarter_ordinal)
    date.year_modifier.append(match.fact.year_modifier)
    date.year_cardinal.append(match.fact.year_cardinal)
    date.week_modifier.append(match.fact.week_modifier)
    date.week_ordinal.append(match.fact.week_ordinal)
    date.week_cardinal.append(match.fact.week_cardinal)
    date.month_ordinal.append(match.fact.month_ordinal)
    date.month_modifier.append(match.fact.month_modifier)
    date.day_cardinal.append(match.fact.day_cardinal)
    date.day_ordinal.append(match.fact.day_ordinal)
    date.start_date.append(match.fact.start_date)
    date.end_date.append(match.fact.end_date)
    date.day_modifier.append(match.fact.day_modifier)
    date.half_year.append(match.fact.half_year)
    date.count.append(match.fact.count)
    date.date.append(match.fact.date)
    #date.day.append(match.fact.day)
  if len(str(skip_none(date.quarter_cardinal))) > 0:  
    print("quarter_cardinal: ", skip_none(date.quarter_cardinal))
  if len(str(skip_none(date.quarter_ordinal))) > 0:  
    print("quarter_ordinal: ", skip_none(date.quarter_ordinal))
  if len(str(skip_none(date.year_modifier))) > 0:  
    print("year_modifier: ", skip_none(date.year_modifier))
  if len(str(skip_none(date.year_cardinal))) > 0:  
    print("year_cardinal: ", skip_none(date.year_cardinal))
  if len(str(skip_none(date.date))) > 0:  
    print("date: ", skip_none(date.date))
  if len(str(skip_none(date.week_ordinal))) > 0:  
    print("week_ordinal: ", skip_none(date.week_ordinal))
  if len(str(skip_none(date.week_cardinal))) > 0:  
    print("week_cardinal: ", skip_none(date.week_cardinal))  
  if len(str(skip_none(date.week_modifier))) > 0:  
    print("week_modifier: ", skip_none(date.week_modifier)) 
  if len(str(skip_none(date.month_ordinal))) > 0:  
    print("month_ordinal: ", skip_none(date.month_ordinal))
  if len(str(skip_none(date.month_modifier))) > 0:  
    print("month_modifier: ", skip_none(date.month_modifier))       
  if len(str(skip_none(date.day_cardinal))) > 0:  
    print("day_cardinal: ", skip_none(date.day_cardinal))
  if len(str(skip_none(date.day_ordinal))) > 0:  
    print("day_ordinal: ", skip_none(date.day_ordinal))   
  if len(str(skip_none(date.start_date))) > 0:  
    print("start_date: ", skip_none(date.start_date))
  if len(str(skip_none(date.end_date))) > 0:  
    print("end_date: ", skip_none(date.end_date))  
  if len(str(skip_none(date.day_modifier))) > 0:  
    print("day_modifier: ", skip_none(date.day_modifier)) 
  if len(str(skip_none(date.half_year))) > 0:  
    print("half_year: ", skip_none(date.half_year))   
  if len(str(skip_none(date.count))) > 0:  
    print("count: ", skip_none(date.count))              
  #print("Квартал: ", skip_none(date.quater))
  #print("Месяц: ", skip_none(date.month))
  #print("Неделя: ", skip_none(date.week))
  #print("День: ", skip_none(date.day))

# %%
from yargy.parser import prepare_trees
from yargy import Parser, or_, rule
from yargy import (
    rule,
    and_, or_, not_
)
from yargy.interpretation import fact
from yargy.predicates import (
    eq, gte, lte, length_eq,
    dictionary, normalized,
)
from yargy.predicates import (
    eq, in_, dictionary,
    type, gram
)

Date = fact(
    'Date',
    #['year', 'quater', 'month','week',  'day']
    ['week_ordinal','week_cardinal','week_modifier', 'week_start_ordinal', 'week_end_ordinal',

'quarter_ordinal','quarter_cardinal','quarter_start_ordinal','quarter_end_ordinal',

'month_modifier','month_ordinal','month_cardinal',

'year_modifier','year_cardinal','year_start_modifier','year_end_modifier',

'half_year','count', 

'day_ordinal', 'day_cardinal', 'day_modifier',

'date', 'date_month', 'start_date', 'end_date']
)


class Date(Date):
    @property
    def obj(self):
        from natasha import obj
        return obj.Date(#self.year ,self.quater, self.month , self.week,self.day ,
                        self.week_ordinal ,self.week_cardinal ,self.week_modifier,self.week_start_ordinal,self.week_end_ordinal,
        self.quarter_ordinal,self.quarter_cardinal,self.quarter_start_ordinal,self.quarter_end_ordinal,self.month_modifier,
        self.month_ordinal,self.month_cardinal,self.date_month, self.year_modifier,self.year_cardinal,self.year_start_modifier,
        self.half_year,self.count,  
        self.year_end_modifier,self.date,self.day_ordinal, self.day_cardinal, self.day_modifier, self.start_date,self.end_date
        )

INT = type('INT')
NOUN = gram('NOUN')
ADJF = gram('ADJF')
PRTF = gram('PRTF')
GENT = gram('gent')
NUMR = gram('NUMR')
DOT = eq('.')

MONTHS = {
    'январь': 1,
    'февраль': 2,
    'март': 3,
    'апрель': 4,
    'май': 5,
    'июнь': 6,
    'июль': 7,
    'август': 8,
    'сентябрь': 9,
    'октябрь': 10,
    'ноябрь': 11,
    'декабрь': 12,
    'текущий': 0, 
}
MODIFIERS = {
    'текущий': 0,
    'прошлый': -1, 
    'позапрошлый': -2, 
    'позавчерашний':-2,
    'прошедшее': -1,
    'последний': -0.5, 
    'прошлый' : -1,
    'предыдущий':-1, 
    'вчерашний': -1,
    'истекший': -1,
    'прошлое': -1,
    'прошлого' : -1 , 
    'три': 3,
    'один':1,
    '2019':2019
}

FROM_STR_TO_INT = {
    'апрель':4,
    'за':1,
    'три': 3, 
    'второй': 2,
    'первый': 1,
    'третий':3,
    '4':4,
    '1':1,
    '3':3,
    '2':2,
    'две':2,
    '2й':2,
    '2ю':2,
    '10':10,
    'один': 1,
    'прошлый': -1,
    'четвёртый':4 ,
    'четыре': 4,
    'два': 2,
    'десять':10,
    'последний': -0.5,
    'предыдущий': -1,
    'двадцать':20,
    'сегодня': 0, 
    'вчера': -1, 
    'позавчера':-2,
    'последнее': -0.5,
    'прошлое': -1,
    'второе':2,
    'назад': -1, 
    'первое':1, 
    'третье':3, 
     'четвертовать':4
}


YEAR_WORD = or_(
    rule('г', eq('.').optional()),
    rule(normalized('год')), 
    rule('года')
)

YEAR_STR = or_(
    ADJF
).interpretation(
    Date.year_modifier.normalized().custom(MODIFIERS.__getitem__)
)
YEAR_INT = or_(
    
    NUMR
).interpretation(
    Date.year_cardinal.normalized().custom(FROM_STR_TO_INT.__getitem__)
)
YEAR = and_(
    gte(1000),
    lte(2100)
).interpretation(
    Date.year_cardinal.custom(int)
)

YEAR_SHORT = and_(
    length_eq(2),
    gte(0),
    lte(99)
).interpretation(
    Date.year_cardinal.custom(lambda _: 1900 + int(_))
)



QUATER_WORD = or_(
    rule(normalized('квартал')), 
    rule('квартала')
)

QUATER_INT = or_(
    INT, 
    NUMR
).interpretation(
    Date.quarter_cardinal.normalized().custom(FROM_STR_TO_INT.__getitem__)
)

QUATER_ADJF= or_(
    ADJF
).interpretation(
    Date.quarter_ordinal.normalized().custom(FROM_STR_TO_INT.__getitem__)
)


ADJF_INT_NUMR= or_(
    #ADJF,
    INT, 
    NUMR
)

MODIFIER = or_(
    eq(normalized('прошлую')),
    eq(normalized('прошлый')), 
    eq(normalized('предыдущий')), 
    eq(normalized('прошлого')), 
    eq(normalized('прошлое')),
    eq(normalized('последний')), 
    eq('последнее')
)

MONTH_MODIFIER = or_(
    eq(normalized('прошлую')),
    eq('прошлый'), 
    eq('предыдущий'), 
    eq('прошлого'), 
    eq('прошлое'),
    eq('последний')
).interpretation(
    Date.month_modifier.normalized().custom(MODIFIERS.__getitem__)
)

MONTH_NAME = dictionary(MONTHS).interpretation(
    Date.month_ordinal.normalized().custom(MONTHS.__getitem__)
)

MONTH = and_(
    gte(1),
    lte(12)
).interpretation(
    Date.month_ordinal.custom(int)
)

MONTH_WORD = or_(
    rule(normalized('месяц'))
)

MONTH_STR = not_(
    or_(
    eq(normalized('прошлую')),
    eq('прошлый'), 
    eq('предыдущий'), 
    eq('прошлого'), 
    eq('прошлое'),
    eq('последний'), 
    eq('март'),
    eq(normalized('апрель')))

).interpretation(
    Date.month_ordinal.normalized().custom(FROM_STR_TO_INT.__getitem__)
)


WEEK_WORD = or_(
    rule(normalized('неделя'))
)

WEEK_MODIFIER = or_(
    eq('прошлую'),
    eq('прошлый'), 
    eq('прошлое'), 
    eq('последний')
).interpretation(
    Date.week_modifier.normalized().custom(MODIFIERS.__getitem__)
)

WEEK_ORIG= not_(
     
    or_(
    eq('три'),     
    eq('прошлую'),
    eq('прошлый'), 
    eq('прошлое'),
    eq('последний'))
).interpretation(
    Date.week_ordinal.normalized().custom(FROM_STR_TO_INT.__getitem__)
)
WEEK_CARD = or_(
    eq('три')
).interpretation(
    Date.week_cardinal.normalized().custom(FROM_STR_TO_INT.__getitem__)
)

DAY = and_(
    gte(1),
    lte(31)
).interpretation(
    Date.day_ordinal.custom(int)
)

DAY_STR = not_(
    or_(
    eq(normalized('прошлую')),
    eq('прошлый'), 
    eq('предыдущий'), 
    eq('прошлого'), 
    eq('прошлое'), 
    eq('последний'))
).interpretation(
    Date.day_ordinal.normalized().custom(FROM_STR_TO_INT.__getitem__)
)
DAY_INT = or_(
    NUMR
).interpretation(
    Date.day_cardinal.normalized().custom(FROM_STR_TO_INT.__getitem__)
)
DAY_WORD  = or_ (
    rule(normalized('день'))
)
PERIOD_START = or_(
    
)

ALL_WORD = not_(
    eq('fkn')
)

DAY_MODIFIER = or_(
    eq('прошлую'),
    eq('прошлый'), 
    eq('прошлое'), 
    eq('последний'), 
    eq("предыдущий")
).interpretation(
    Date.day_modifier.normalized().custom(MODIFIERS.__getitem__)
)
multipleDATE = or_(
    rule(
        eq('с'),
        ADJF.optional().interpretation(Date.start_date.custom(str)),
        NOUN.optional().interpretation(Date.start_date.custom(str)),
        
        eq('по'),
          
        ADJF.optional().interpretation(Date.end_date.custom(str)),
        NOUN.optional().interpretation(Date.end_date.custom(str)),       
    ), 
    #DATE
)

DATE = or_(
    rule(
        or_(eq('сегодня'),eq("вчера") ,eq('позавчера')).interpretation(Date.day_ordinal.custom(FROM_STR_TO_INT.__getitem__))
        
    ),
    rule(
        ADJF_INT_NUMR.optional().interpretation(Date.count),
        DAY_MODIFIER, 
        DAY_WORD        
    ),
    rule(
        ADJF_INT_NUMR.optional(), 
        DAY_WORD        
    ),

    rule(
        or_(INT, NUMR).optional().interpretation(Date.count.custom(FROM_STR_TO_INT.__getitem__)),
        DAY_STR, 
        DAY_WORD        
    ),
    rule(
        WEEK_CARD, 
        WEEK_WORD        
    ),
    
    rule(
        or_(INT, NUMR).optional().interpretation(Date.count.custom(FROM_STR_TO_INT.__getitem__)),
        WEEK_ORIG, 
        WEEK_WORD        
    ),
    rule(
        or_(INT, NUMR).optional().interpretation(Date.count.custom(FROM_STR_TO_INT.__getitem__)),
        WEEK_MODIFIER, 
        WEEK_WORD        
    ),
    rule(
        or_(INT, NUMR).optional().interpretation(Date.count.custom(FROM_STR_TO_INT.__getitem__)),
        MONTH_MODIFIER, 
        MONTH_WORD
    ),
    rule(
        or_(INT, NUMR).optional().interpretation(Date.count.custom(FROM_STR_TO_INT.__getitem__)),
        MONTH_STR, 
        MONTH_WORD
    ),
    rule(
        
        MONTH_NAME , 
        MONTH_WORD.optional() 
    ),
    rule(
        
        QUATER_INT, 
        QUATER_WORD 
    ),
    
    rule(
        or_(INT, NUMR).optional().interpretation(Date.count.custom(FROM_STR_TO_INT.__getitem__)),
        QUATER_ADJF, 
        QUATER_WORD 
    ),
    rule(
        or_(INT, NUMR).optional().interpretation(Date.count.custom(FROM_STR_TO_INT.__getitem__)),
        YEAR_STR,
        YEAR_WORD
    ),
    rule(
        ALL_WORD.interpretation(Date.half_year.normalized().custom(FROM_STR_TO_INT.__getitem__)),
        or_(eq('полугодие'),eq('полугодия'))
         
        
    ),
    rule(
        
        YEAR_WORD,
        or_(INT, NUMR).interpretation(Date.year_modifier) ,
        eq('назад')
    ),  
    rule(
        YEAR_INT,
        YEAR_WORD
    ), 
    rule(
        or_(INT, NUMR).optional().interpretation(Date.count.custom(FROM_STR_TO_INT.__getitem__)),
        YEAR,#.optional(), 
        YEAR_WORD 
    ),
    rule(
        YEAR_SHORT, 
        YEAR_WORD 
    ), 
    rule(
        #INT.optional().interpretation(Date.year_modifier),
        YEAR_WORD,
        eq('назад').optional().interpretation(Date.year_cardinal.custom(FROM_STR_TO_INT.__getitem__)) 
    ),
    rule(
        YEAR
    )
).interpretation(
    Date
)

# %%
from natasha import (
    MorphVocab,
    DatesExtractor
)
from IPython.display import display
from yargy.parser import prepare_trees
import re
from yargy.tokenizer import MorphTokenizer
from yargy import (
    Parser,
    or_, rule
)
from yargy.predicates import (
    eq, in_, dictionary,
    type, gram
)

INT = type('INT')
NOUN = gram('NOUN')
ADJF = gram('ADJF')
PRTF = gram('PRTF')
GENT = gram('gent')
NUMR = gram('NUMR')
DOT = eq('.')

TOKENIZER = MorphTokenizer()
morph_vocab = MorphVocab()
parser = Parser(DATE)
#dates_extractor = DATE(morph_vocab)

# %%
line = ' за квартал '
split_on_date = re.split(r'с |по | до ', line )
for split in split_on_date:
  date = ExtractDate()
  matches = parser.extract(split)
  viz(date , split, matches, len(split_on_date))

# %%
import re

str_num = 1
for line in all_tests:
  print(str_num, "Исходный текст: ", line)
  str_num = str_num + 1
  split_on_date = re.split(r'с |по | до ', line )
  for split in split_on_date:
    date = ExtractDate()
    matches = parser.extract(split)
    #print("______________________")
    #print(split)
    #try:
    viz(date , split, matches, len(split_on_date))
    #except:
    #  print("Can't parse")
  print("========================")
# Out:
# 1 Исходный текст:   за сегодня
# day_ordinal:  0
# ========================
# 2 Исходный текст:   за вчера
# day_ordinal:  -1
# ========================
# 3 Исходный текст:   за позавчера
# day_ordinal:  -2
# ========================
# 4 Исходный текст:   за последний день
# day_modifier:  -0.5
# ========================
# 5 Исходный текст:   за последнюю неделю
# week_ordinal:  -0.5
# ========================
# 6 Исходный текст:   за последний месяц
# month_modifier:  -0.5
# ========================
# 7 Исходный текст:   за последний квартал
# quarter_ordinal:  -0.5
# ========================
# 8 Исходный текст:   за последнее полугодие
# half_year:  -0.5
# ========================
# 9 Исходный текст:   за последний год
# year_modifier:  -0.5
# ========================
# 10 Исходный текст:   за последние два дня
# day_ordinal:  2
# ========================
# 11 Исходный текст:   за последние три недели
# week_cardinal:  3
# ========================
# 12 Исходный текст:   за последние четыре месяца
# month_ordinal:  4
# ========================
# 13 Исходный текст:   за последние два квартал
# quarter_cardinal:  2
# ========================
# 14 Исходный текст:   за последние три года
# year_cardinal:  3
# ========================
# 15 Исходный текст:   за прошлый день
# day_modifier:  -1
# ========================
# 16 Исходный текст:   за прошлую неделю
# week_modifier:  -1
# ========================
# 17 Исходный текст:   за прошлый месяц
# month_modifier:  -1
# ========================
# 18 Исходный текст:   за прошлый квартал
# quarter_ordinal:  -1
# ========================
# 19 Исходный текст:   за прошлое полугодие
# half_year:  -1
# ========================
# 20 Исходный текст:   за прошлый год
# year_modifier:  -1
# ========================
# 21 Исходный текст:   за два прошлых дня
# day_ordinal:  -1
# count:  2
# ========================
# 22 Исходный текст:   за две прошлых недели
# week_ordinal:  -1
# count:  2
# ========================
# 23 Исходный текст:   за три прошлых месяца
# month_ordinal:  -1
# count:  3
# ========================
# 24 Исходный текст:   за четыре прошлых года
# year_modifier:  -1
# count:  4
# ========================
# 25 Исходный текст:   за предыдущий день
# day_modifier:  -1
# ========================
# 26 Исходный текст:   за предыдущую неделю
# week_ordinal:  -1
# ========================
# 27 Исходный текст:   за предыдущий месяц
# month_modifier:  -1
# ========================
# 28 Исходный текст:   за предыдущий квартал
# quarter_ordinal:  -1
# ========================
# 29 Исходный текст:   за предыдущее полугодие
# half_year:  -1
# ========================
# 30 Исходный текст:   за предыдущий год
# year_modifier:  -1
# ========================
# 31 Исходный текст:   за два предыдущих дня
# day_ordinal:  -1
# count:  2
# ========================
# 32 Исходный текст:   за две предыдущих недели
# week_ordinal:  -1
# count:  2
# ========================
# 33 Исходный текст:   за три предыдущих месяца
# month_ordinal:  -1
# count:  3
# ========================
# 34 Исходный текст:   за четыре предыдущих года
# year_modifier:  -1
# count:  4
# ========================
# 35 Исходный текст:   за день
# day_ordinal:  1
# ========================
# 36 Исходный текст:   за один день
# day_ordinal:  1
# ========================
# 37 Исходный текст:   за три дня
# day_ordinal:  3
# ========================
# 38 Исходный текст:   за десять дней
# day_ordinal:  10
# ========================
# 39 Исходный текст:   за двадцать дней
# day_ordinal:  20
# ========================
# 40 Исходный текст:   за 1 день
# day_ordinal:  1
# ========================
# 41 Исходный текст:   за 3 дня
# day_ordinal:  3
# ========================
# 42 Исходный текст:   за 10 дней
# day_ordinal:  10
# ========================
# 43 Исходный текст:   за неделю
# week_ordinal:  1
# ========================
# 44 Исходный текст:   за одну неделю
# week_ordinal:  1
# ========================
# 45 Исходный текст:   за три недели
# week_cardinal:  3
# ========================
# 46 Исходный текст:   за десять недель
# week_ordinal:  10
# ========================
# 47 Исходный текст:   за 1 неделю
# week_ordinal:  1
# ========================
# 48 Исходный текст:   за 3 недели
# week_ordinal:  3
# ========================
# 49 Исходный текст:   за 10 недель
# week_ordinal:  10
# ========================
# 50 Исходный текст:   за месяц
# month_ordinal:  1
# ========================
# 51 Исходный текст:   за один месяц
# month_ordinal:  1
# ========================
# 52 Исходный текст:   за три месяца
# month_ordinal:  3
# ========================
# 53 Исходный текст:   за десять месяцев
# month_ordinal:  10
# ========================
# 54 Исходный текст:   за 1 месяц
# month_ordinal:  1
# ========================
# 55 Исходный текст:   за 2 месяца
# month_ordinal:  2
# ========================
# 56 Исходный текст:   за 3 месяца
# month_ordinal:  3
# ========================
# 57 Исходный текст:   за 10 месяцев
# month_ordinal:  10
# ========================
# 58 Исходный текст:   за квартал
# ========================
# 59 Исходный текст:   за один квартал
# quarter_ordinal:  1
# ========================
# 60 Исходный текст:   за три квартала
# quarter_cardinal:  3
# ========================
# 61 Исходный текст:   за 1 квартал
# quarter_cardinal:  1
# ========================
# 62 Исходный текст:   за 3 месяца
# month_ordinal:  3
# ========================
# 63 Исходный текст:   за полугодие
# half_year:  1
# ========================
# 64 Исходный текст:   за два полугодия
# half_year:  2
# ========================
# 65 Исходный текст:   за 2 полугодя
# ========================
# 66 Исходный текст:   за год
# ========================
# 67 Исходный текст:   за один год
# year_modifier:  1
# ========================
# 68 Исходный текст:   за три года
# year_cardinal:  3
# ========================
# 69 Исходный текст:   за десять лет
# year_cardinal:  10
# ========================
# 70 Исходный текст:   за 1 год
# ========================
# 71 Исходный текст:   за 3 года
# ========================
# 72 Исходный текст:   три дня назад
# day_ordinal:  3
# ========================
# 73 Исходный текст:   две недели назад
# week_ordinal:  2
# ========================
# 74 Исходный текст:   два месяца назад
# month_ordinal:  2
# ========================
# 75 Исходный текст:   полгода назад
# ========================
# 76 Исходный текст:   год назад
# year_cardinal:  -1
# ========================
# 77 Исходный текст:   на прошлой неделе
# week_ordinal:  -1
# ========================
# 78 Исходный текст:   за январь
# month_ordinal:  1
# ========================
# 79 Исходный текст:   за март 2012го
# year_cardinal:  2012
# month_ordinal:  3
# ========================
# 80 Исходный текст:   за апрель 2008
# year_cardinal:  2008
# month_ordinal:  4
# ========================
# 81 Исходный текст:   за август 2019 года
# year_cardinal:  2019
# month_ordinal:  8
# ========================
# 82 Исходный текст:   за 2011 год
# year_cardinal:  2011
# ========================
# 83 Исходный текст:   за 2012й
# year_cardinal:  2012
# ========================
# 84 Исходный текст:   за 2021
# year_cardinal:  2021
# ========================
# 85 Исходный текст:   за второй квартал
# quarter_ordinal:  2
# ========================
# 86 Исходный текст:   за июнь прошлого года
# year_modifier:  -1
# month_ordinal:  6
# ========================
# 87 Исходный текст:   за август позапрошлого года
# year_modifier:  -2
# month_ordinal:  8
# ========================
# 88 Исходный текст:   за первый квартал текущего года
# quarter_ordinal:  1
# year_modifier:  0
# month_ordinal:  0
# ========================
# 89 Исходный текст:   за третий квартал позапрошлого года
# quarter_ordinal:  3
# year_modifier:  -2
# ========================
# 90 Исходный текст:   за 2й квартал прошлого года
# year_modifier:  -1
# ========================
# 91 Исходный текст:   за третий квартал предыдущего года
# quarter_ordinal:  3
# year_modifier:  -1
# ========================
# 92 Исходный текст:   за март месяц прошедшего года
# year_modifier:  -1
# month_ordinal:  3
# ========================
# 93 Исходный текст:   за февраль прошлого года
# year_modifier:  -1
# month_ordinal:  2
# ========================
# 94 Исходный текст:   за второе полугодие прошлого года
# year_modifier:  -1
# half_year:  2
# ========================
# 95 Исходный текст:   за 2 неделю прошлого месяца
# week_ordinal:  2
# month_modifier:  -1
# ========================
# 96 Исходный текст:   за первую неделю сентября прошлого года
# year_modifier:  -1
# week_ordinal:  1
# month_ordinal:  9
# ========================
# 97 Исходный текст:   за первый месяц 2020 года
# year_cardinal:  2020
# month_ordinal:  1
# ========================
# 98 Исходный текст:   за второй день третьей недели второго квартала
# quarter_ordinal:  2
# week_ordinal:  3
# day_ordinal:  2
# ========================
# 99 Исходный текст:   за 4 квартал 2020 года
# quarter_cardinal:  4
# year_cardinal:  2020
# ========================
# 100 Исходный текст:   за три недели первого квартала 2019 года
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-857fe40d4912> in <module>
#      12     #print(split)
#      13     #try:
# ---> 14     viz(date , split, matches, len(split_on_date))
#      15     #except:
#      16     #  print("Can't parse")
#
# <ipython-input-7-477c6b81fae4> in viz(date, line, matches, count_date)
#      74     #    print(chank)
#      75     #display(match.tree.as_dot)
# ---> 76     date.quarter_cardinal.append(match.fact.quarter_cardinal)
#      77     date.quarter_ordinal.append(match.fact.quarter_ordinal)
#      78     date.year_modifier.append(match.fact.year_modifier)
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/parser.py in fact(self)
#     188     @property
#     189     def fact(self):
# --> 190         fact = self.tree.interpret()
#     191         return fact.normalized
#     192
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/tree/constructors.py in interpret(self)
#      40             InterpretationTransformator
#      41         )
# ---> 42         return self.transform(
#      43             KeepInterpretationNodesTransformator,
#      44             InterpretationTransformator
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/tree/constructors.py in transform(self, *transformators)
#      18
#      19     def transform(self, *transformators):
# ---> 20         return TransformatorsComposition(transformators)(self)
#      21
#      22     @property
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/visitor.py in __call__(self, item)
#      26     def __call__(self, item):
#      27         for transformator in self.transformators:
# ---> 28             item = transformator()(item)
#      29         return item
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/tree/transformators.py in __call__(self, tree)
#      92 class InterpretationTransformator(TreeTransformator):
#      93     def __call__(self, tree):
# ---> 94         return self.visit(tree.root)
#      95
#      96     def visit_Node(self, item):
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/visitor.py in visit(self, item)
#      15
#      16     def visit(self, item):
# ---> 17         return self.resolve_method(item)(item)
#      18
#      19
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/tree/transformators.py in visit_Node(self, item)
#      95
#      96     def visit_Node(self, item):
# ---> 97         input = InterpretatorInput(self.visit(_) for _ in item.children)
#      98         if isinstance(item.production, PipelineProduction):
#      99             input.key = item.production.value
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/interpretation/interpretator.py in __init__(self, items, key)
#      28
#      29     def __init__(self, items, key=None):
# ---> 30         self.items = list(items)
#      31         self.key = key
#      32
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/tree/transformators.py in <genexpr>(.0)
#      95
#      96     def visit_Node(self, item):
# ---> 97         input = InterpretatorInput(self.visit(_) for _ in item.children)
#      98         if isinstance(item.production, PipelineProduction):
#      99             input.key = item.production.value
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/visitor.py in visit(self, item)
#      15
#      16     def visit(self, item):
# ---> 17         return self.resolve_method(item)(item)
#      18
#      19
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/tree/transformators.py in visit_Node(self, item)
#      98         if isinstance(item.production, PipelineProduction):
#      99             input.key = item.production.value
# --> 100         return item.interpretator(input)
#     101
#     102     def visit_Leaf(self, item):
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/interpretation/interpretator.py in __call__(self, items)
#     219
#     220     def __call__(self, items):
# --> 221         value = NormalizerInterpretator.__call__(self, items)
#     222         return AttributeResult(value, self.attribute)
#     223
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/interpretation/interpretator.py in __call__(self, input)
#     203                     types=[type(_) for _ in items]
#     204                 ))
# --> 205             value = self.normalizer(input)
#     206         return NormalizerResult(value, input)
#     207
#
# ~/opt/miniconda3/envs/DateParse/lib/python3.8/site-packages/yargy/interpretation/normalizer.py in __call__(self, items)
#     126     def __call__(self, items):
#     127         value = self.morph(items)
# --> 128         return self.function(value)
#     129
#     130     @property
#
# KeyError: 'первое'

# %% [markdown]
# # Измеряем качество

# %%
tests = [
' за сегодня ' ,
' за вчера ' ,
' за позавчера ' ,
' за последний день ' ,
' за последнюю неделю ' ,
' за последний месяц ' ,
' за последний квартал ' ,
' за последнее полугодие ']

# %%
class ExtractDate(object):

  def __init__(self):
        self.year = []
        self.quater = []
        self.month = []
        self.week = []
        self.day = [] 

        self.week_ordinal = []
        self.week_cardinal = []
        self.week_modifier = []
        self.week_start_ordinal= []
        self.week_end_ordinal= []

        self.quarter_ordinal= []
        self.quarter_cardinal= []
        self.quarter_start_ordinal= []
        self.quarter_end_ordinal= []

        self.month_modifier= []
        self.month_ordinal= []
        self.month_cardinal= []

        self.half_year = []
        self.count = []

        self.year_modifier= []
        self.year_cardinal= []
        self.year_start_modifier= []
        self.year_end_modifier= []

        self.date= []

        self.day_ordinal= []
        self.day_cardinal= []
        self.day_modifier = []

        self.start_date= []
        self.end_date= []
        

  def get_date(self):
      if self.year != None:
            print("Год: ", match.fact.year)
      if self.quater != None:
            print("Квартал: ", match.fact.quater)
      if self.mouth != None:
            print("Месяц: ", match.fact.mouth)
      if self.week != None:
            print("Неделя: ", match.fact.week)
      if self.day != None:
            print("День: ", match.fact.day)  

def skip_none(arr):
  #print("arr", arr)
  out = ''
  for el in arr:
    #print(el)
    if el != None:
      out = el
  return out    

dict_num_day_ordinal = {}
def viz(str_num,  date ,line, matches, count_date): 
  #result = []
  #str_num_day
  #print(matches)

  for match in matches:
    #print("________________________")
    #print("Дата: ", line)
    #print(match.fact)
    #for chank in match.fact:
    #  if chank != None:
    #    print(chank)
    #display(match.tree.as_dot)
    date.quarter_cardinal.append(match.fact.quarter_cardinal)
    date.quarter_ordinal.append(match.fact.quarter_ordinal)
    date.year_modifier.append(match.fact.year_modifier)
    date.year_cardinal.append(match.fact.year_cardinal)
    date.week_modifier.append(match.fact.week_modifier)
    date.week_ordinal.append(match.fact.week_ordinal)
    date.week_cardinal.append(match.fact.week_cardinal)
    date.month_ordinal.append(match.fact.month_ordinal)
    date.month_modifier.append(match.fact.month_modifier)
    date.day_cardinal.append(match.fact.day_cardinal)
    date.day_ordinal.append(match.fact.day_ordinal)
    date.start_date.append(match.fact.start_date)
    date.end_date.append(match.fact.end_date)
    date.day_modifier.append(match.fact.day_modifier)
    date.half_year.append(match.fact.half_year)
    date.count.append(match.fact.count)
    date.date.append(match.fact.date)
    #date.day.append(match.fact.day)
  '''if len(str(skip_none(date.quarter_cardinal))) > 0:  
    print("quarter_cardinal: ", skip_none(date.quarter_cardinal))
  if len(str(skip_none(date.quarter_ordinal))) > 0:  
    print("quarter_ordinal: ", skip_none(date.quarter_ordinal))
  if len(str(skip_none(date.year_modifier))) > 0:  
    print("year_modifier: ", skip_none(date.year_modifier))
  if len(str(skip_none(date.year_cardinal))) > 0:  
    print("year_cardinal: ", skip_none(date.year_cardinal))
  if len(str(skip_none(date.date))) > 0:  
    print("date: ", skip_none(date.date))
  if len(str(skip_none(date.week_ordinal))) > 0:  
    print("week_ordinal: ", skip_none(date.week_ordinal))
  if len(str(skip_none(date.week_cardinal))) > 0:  
    print("week_cardinal: ", skip_none(date.week_cardinal))  
  if len(str(skip_none(date.week_modifier))) > 0:  
    print("week_modifier: ", skip_none(date.week_modifier)) 
  if len(str(skip_none(date.month_ordinal))) > 0:  
    print("month_ordinal: ", skip_none(date.month_ordinal))
  if len(str(skip_none(date.month_modifier))) > 0:  
    print("month_modifier: ", skip_none(date.month_modifier))       
  if len(str(skip_none(date.day_cardinal))) > 0:  
    print("day_cardinal: ", skip_none(date.day_cardinal))'''
  if len(str(skip_none(date.day_ordinal))) > 0:  
    print("day_ordinal: ", skip_none(date.day_ordinal))  
    #pred_day_ordinal.append(skip_none(date.day_ordinal)) 
    #num_day_ordinal.append(str_num)
    dict_num_day_ordinal["{}".format(line)] = skip_none(date.day_ordinal)
  '''if len(str(skip_none(date.start_date))) > 0:  
    print("start_date: ", skip_none(date.start_date))
  if len(str(skip_none(date.end_date))) > 0:  
    print("end_date: ", skip_none(date.end_date))  
  if len(str(skip_none(date.day_modifier))) > 0:  
    print("day_modifier: ", skip_none(date.day_modifier)) 
  if len(str(skip_none(date.half_year))) > 0:  
    print("half_year: ", skip_none(date.half_year))   
  if len(str(skip_none(date.count))) > 0:  
    print("count: ", skip_none(date.count))              
  #print("Квартал: ", skip_none(date.quater))
  #print("Месяц: ", skip_none(date.month))
  #print("Неделя: ", skip_none(date.week))
  #print("День: ", skip_none(date.day))'''

# %%
import re
num_day_ordinal = []
str_num = 0
pred_day_ordinal = []
for line in all_tests:
  print(str_num, "Исходный текст: ", line)
  str_num = str_num + 1
  split_on_date = re.split(r'с |по | до ', line )
  for split in split_on_date:
    date = ExtractDate()
    matches = parser.extract(split)
    #print("______________________")
    #print(split)
    #try:
    viz(str_num, date , split, matches, len(split_on_date))
    #except:
    #  print("Can't parse")
  print("========================")
# Out:
# 0 Исходный текст:   за сегодня
# day_ordinal:  0
# ========================
# 1 Исходный текст:   за вчера
# day_ordinal:  -1
# ========================
# 2 Исходный текст:   за позавчера
# day_ordinal:  -2
# ========================
# 3 Исходный текст:   за последний день
# ========================
# 4 Исходный текст:   за последнюю неделю
# ========================
# 5 Исходный текст:   за последний месяц
# ========================
# 6 Исходный текст:   за последний квартал
# ========================
# 7 Исходный текст:   за последнее полугодие
# ========================
# 8 Исходный текст:   за последний год
# ========================
# 9 Исходный текст:   за последние два дня
# day_ordinal:  2
# ========================
# 10 Исходный текст:   за последние три недели
# ========================
# 11 Исходный текст:   за последние четыре месяца
# ========================
# 12 Исходный текст:   за последние два квартал
# ========================
# 13 Исходный текст:   за последние три года
# ========================
# 14 Исходный текст:   за прошлый день
# ========================
# 15 Исходный текст:   за прошлую неделю
# ========================
# 16 Исходный текст:   за прошлый месяц
# ========================
# 17 Исходный текст:   за прошлый квартал
# ========================
# 18 Исходный текст:   за прошлое полугодие
# ========================
# 19 Исходный текст:   за прошлый год
# ========================
# 20 Исходный текст:   за два прошлых дня
# day_ordinal:  -1
# ========================
# 21 Исходный текст:   за две прошлых недели
# ========================
# 22 Исходный текст:   за три прошлых месяца
# ========================
# 23 Исходный текст:   за четыре прошлых года
# ========================
# 24 Исходный текст:   за предыдущий день
# ========================
# 25 Исходный текст:   за предыдущую неделю
# ========================
# 26 Исходный текст:   за предыдущий месяц
# ========================
# 27 Исходный текст:   за предыдущий квартал
# ========================
# 28 Исходный текст:   за предыдущее полугодие
# ========================
# 29 Исходный текст:   за предыдущий год
# ========================
# 30 Исходный текст:   за два предыдущих дня
# day_ordinal:  -1
# ========================
# 31 Исходный текст:   за две предыдущих недели
# ========================
# 32 Исходный текст:   за три предыдущих месяца
# ========================
# 33 Исходный текст:   за четыре предыдущих года
# ========================
# 34 Исходный текст:   за день
# day_ordinal:  1
# ========================
# 35 Исходный текст:   за один день
# day_ordinal:  1
# ========================
# 36 Исходный текст:   за три дня
# day_ordinal:  3
# ========================
# 37 Исходный текст:   за десять дней
# day_ordinal:  10
# ========================
# 38 Исходный текст:   за двадцать дней
# day_ordinal:  20
# ========================
# 39 Исходный текст:   за 1 день
# day_ordinal:  1
# ========================
# 40 Исходный текст:   за 3 дня
# day_ordinal:  3
# ========================
# 41 Исходный текст:   за 10 дней
# day_ordinal:  10
# ========================
# 42 Исходный текст:   за неделю
# ========================
# 43 Исходный текст:   за одну неделю
# ========================
# 44 Исходный текст:   за три недели
# ========================
# 45 Исходный текст:   за десять недель
# ========================
# 46 Исходный текст:   за 1 неделю
# ========================
# 47 Исходный текст:   за 3 недели
# ========================
# 48 Исходный текст:   за 10 недель
# ========================
# 49 Исходный текст:   за месяц
# ========================
# 50 Исходный текст:   за один месяц
# ========================
# 51 Исходный текст:   за три месяца
# ========================
# 52 Исходный текст:   за десять месяцев
# ========================
# 53 Исходный текст:   за 1 месяц
# ========================
# 54 Исходный текст:   за 2 месяца
# ========================
# 55 Исходный текст:   за 3 месяца
# ========================
# 56 Исходный текст:   за 10 месяцев
# ========================
# 57 Исходный текст:   за квартал
# ========================
# 58 Исходный текст:   за один квартал
# ========================
# 59 Исходный текст:   за три квартала
# ========================
# 60 Исходный текст:   за 1 квартал
# ========================
# 61 Исходный текст:   за 3 месяца
# ========================
# 62 Исходный текст:   за полугодие
# ========================
# 63 Исходный текст:   за два полугодия
# ========================
# 64 Исходный текст:   за 2 полугодя
# ========================
# 65 Исходный текст:   за год
# ========================
# 66 Исходный текст:   за один год
# ========================
# 67 Исходный текст:   за три года
# ========================
# 68 Исходный текст:   за десять лет
# ========================
# 69 Исходный текст:   за 1 год
# ========================
# 70 Исходный текст:   за 3 года
# ========================
# 71 Исходный текст:   три дня назад
# day_ordinal:  3
# ========================
# 72 Исходный текст:   две недели назад
# ========================
# 73 Исходный текст:   два месяца назад
# ========================
# 74 Исходный текст:   полгода назад
# ========================
# 75 Исходный текст:   год назад
# ========================
# 76 Исходный текст:   на прошлой неделе
# ========================
# 77 Исходный текст:   за январь
# ========================
# 78 Исходный текст:   за март 2012го
# ========================
# 79 Исходный текст:   за апрель 2008
# ========================
# 80 Исходный текст:   за август 2019 года
# ========================
# 81 Исходный текст:   за 2011 год
# ========================
# 82 Исходный текст:   за 2012й
# ========================
# 83 Исходный текст:   за 2021
# ========================
# 84 Исходный текст:   за второй квартал
# ========================
# 85 Исходный текст:   за июнь прошлого года
# ========================
# 86 Исходный текст:   за август позапрошлого года
# ========================
# 87 Исходный текст:   за первый квартал текущего года
# ========================
# 88 Исходный текст:   за третий квартал позапрошлого года
# ========================
# 89 Исходный текст:   за 2й квартал прошлого года
# ========================
# 90 Исходный текст:   за третий квартал предыдущего года
# ========================
# 91 Исходный текст:   за март месяц прошедшего года
# ========================
# 92 Исходный текст:   за февраль прошлого года
# ========================
# 93 Исходный текст:   за второе полугодие прошлого года
# ========================
# 94 Исходный текст:   за 2 неделю прошлого месяца
# ========================
# 95 Исходный текст:   за первую неделю сентября прошлого года
# ========================
# 96 Исходный текст:   за первый месяц 2020 года
# ========================
# 97 Исходный текст:   за второй день третьей недели второго квартала
# day_ordinal:  2
# ========================
# 98 Исходный текст:   за 4 квартал 2020 года
# ========================
# 99 Исходный текст:   за три недели первого квартала 2019 года
# ========================
# 100 Исходный текст:   за вторую неделю сентября 2020 года
# ========================
# 101 Исходный текст:   с апреля 2010 года
# ========================
# 102 Исходный текст:   после апреля 2010 года
# ========================
# 103 Исходный текст:   за апрель 2010 года
# ========================
# 104 Исходный текст:   с мая по июнь 2020 года
# ========================
# 105 Исходный текст:   с февраля по апрель позапрошлого года
# ========================
# 106 Исходный текст:   до июня текущего года
# ========================
# 107 Исходный текст:   с января 2011 года по март 2012го
# ========================
# 108 Исходный текст:   с июня по декабрь
# ========================
# 109 Исходный текст:   с 2001 по 2012 гг
# ========================
# 110 Исходный текст:   с первого до десятого апреля 2019 года
# ========================
# 111 Исходный текст:   с августа по октябрь
# ========================
# 112 Исходный текст:   в апреле
# ========================
# 113 Исходный текст:   в марте 2012 года
# ========================
# 114 Исходный текст:   в апреле прошлого года
# ========================
# 115 Исходный текст:   в мае позапрошлого года
# ========================
# 116 Исходный текст:   во втором квартале
# ========================
# 117 Исходный текст:   в прошлом месяце
# ========================
# 118 Исходный текст:   в прошлом году
# ========================
# 119 Исходный текст:   в позапрошлом году
# ========================
# 120 Исходный текст:   в 2018 году
# ========================
# 121 Исходный текст:   в 2005-2010 годах
# ========================
# 122 Исходный текст:   в 2012-2013 гг
# ========================
# 123 Исходный текст:   с 2012 по 2013
# ========================
# 124 Исходный текст:   c 01.10 по 01.12
# ========================
# 125 Исходный текст:   с 01.02.2003 по 21.12.2012
# ========================
# 126 Исходный текст:   с 01.02 по 21.12
# ========================
# 127 Исходный текст:   с первого октября по первое декабря 2012 года
# ========================
# 128 Исходный текст:   с двадцать второго числа апреля месяца
# ========================
# 129 Исходный текст:   с первого полугодия прошлого года
# ========================
# 130 Исходный текст:   с третьего квартала текущего года
# ========================
# 131 Исходный текст:   со второй по четвертую неделю первого квартала
# ========================
# 132 Исходный текст:   с первого по третий квартал прошлого года
# ========================
# 133 Исходный текст:   с 1 по 3 неделю сентября 2013 года
# ========================
# 134 Исходный текст:   со второго квартала 2019 по третий квартал 2020
# ========================
# 135 Исходный текст:   с января по май 2019 и с первого по третий квартал прошлого года
# ========================
# 136 Исходный текст:   отчет Павлова на портале за прошлую неделю
# ========================
# 137 Исходный текст:   отчет Иванов вики xlsx за прошлый месяц
# ========================
# 138 Исходный текст:   Иванов справка о доходах за прошлый год
# ========================
# 139 Исходный текст:   справка Сидорова pdf три дня назад
# day_ordinal:  3
# ========================
# 140 Исходный текст:   квитанция от Ивана Петровича на прошлой неделе pdf
# ========================
# 141 Исходный текст:   квартальный отчет Светланы docx за прошлый квартал
# ========================

# %%
# accuracy - делим количество правильных ответов на все

def accuracy(true, pred):
    shared_items = {k: true[k] for k in true if k in pred and true[k] == pred[k]}
    return len(shared_items)/len(true)

# %%
#from sklearn.metrics import classification_report

#Для кажого класса (каждой сущьности) получаем качество 
# что делать если не все данные распознаны??
print("Номера тестов с распознанными датами  ", num_day_ordinal)
#true_day_ordinal = [0, 1, 2, 2, 2]

print("Предсказанные day_ordinal", dict_num_day_ordinal)
true_day_ordinal = {' за сегодня ': 0, ' за вчера ': -1, ' за позавчера ': -2, ' за последние два дня ': 2, ' за два прошлых дня ': -2, ' за два предыдущих дня ': -2, ' за день ': 1, ' за один день ': 1, ' за три дня ': 3, ' за десять дней ': 10, ' за двадцать дней ': 20, ' за 1 день ': 1, ' за 3 дня ': 3, ' за 10 дней ': 10, ' три дня назад ': -3, ' за второй день третьей недели второго квартала ': 2, ' справка Сидорова pdf три дня назад ': 3}
print("Правильные day_ordinal", true_day_ordinal)
target_names = ['day_ordinal']
#print(dict_num_day_ordinal)
print(accuracy(true_day_ordinal, dict_num_day_ordinal))
# Out:
# Номера тестов с распознанными датами   []
# Предсказанные day_ordinal {' за сегодня ': 0, ' за вчера ': -1, ' за позавчера ': -2, ' за последние два дня ': 2, ' за два прошлых дня ': -1, ' за два предыдущих дня ': -1, ' за день ': 1, ' за один день ': 1, ' за три дня ': 3, ' за десять дней ': 10, ' за двадцать дней ': 20, ' за 1 день ': 1, ' за 3 дня ': 3, ' за 10 дней ': 10, ' три дня назад ': 3, ' за второй день третьей недели второго квартала ': 2, ' справка Сидорова pdf три дня назад ': 3}
# Правильные day_ordinal {' за сегодня ': 0, ' за вчера ': -1, ' за позавчера ': -2, ' за последние два дня ': 2, ' за два прошлых дня ': -2, ' за два предыдущих дня ': -2, ' за день ': 1, ' за один день ': 1, ' за три дня ': 3, ' за десять дней ': 10, ' за двадцать дней ': 20, ' за 1 день ': 1, ' за 3 дня ': 3, ' за 10 дней ': 10, ' три дня назад ': -3, ' за второй день третьей недели второго квартала ': 2, ' справка Сидорова pdf три дня назад ': 3}
# 0.8235294117647058

# %%
#тесты для  day_cardinal
